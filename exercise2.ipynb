# %%
import numpy as np

# %%
marks = np.array([[78,85,90],
                [45,60,55],
                [88,92,95],
                [30,40,35],
                [65,70,75]])

# %%
print(marks.shape,marks.ndim)
# Out:
# (5, 3) 2

# %%
print(marks.size)
print(marks.dtype)
# Out:
# 15
# int32

# %%
print(marks[1:2])
print(marks[:,2])
print(marks[0,1])
# Out:
# [[45 60 55]]
# [90 55 95 35 75]
# 85

# %%
row_means = np.mean(marks, axis=1)
row_mean = np.mean(marks, axis=0)

# %%
print(row_means)
print(row_mean)
# Out:
# [84.33333333 53.33333333 91.66666667 35.         70.        ]
# [61.2 69.4 70. ]

# %%
status = np.where(row_means >=80)
print(status)
# Out:
# (array([0, 2], dtype=int64),)

# %%
print(marks+5)
# Out:
# [[ 83  90  95]
#  [ 50  65  60]
#  [ 93  97 100]
#  [ 35  45  40]
#  [ 70  75  80]]

# %%
statuss = np.where(marks>=50,1,0)
print(statuss)
# Out:
# [[1 1 1]
#  [0 1 1]
#  [1 1 1]
#  [0 0 0]
#  [1 1 1]]

# %%
st = np.where(marks<40,0,marks)
print(st)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [ 0 40  0]
#  [65 70 75]]

# %%
a = np.where(row_means<50,0,np.where(row_means<70,6,np.where(row_means<85,8,10))) 
# grade = np.where(marks2 < 50, 0, np.where(marks2 < 70, 6, np.where(marks2 < 85 , 8, 10)))
print(a)
# Out:
# [ 8  6 10  0  8]

# %%
marks1 = marks.copy()
marks[0,0] = 0
print(marks)
print(marks1)
# Out:
# [[ 0 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 35]
#  [65 70 75]]
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 35]
#  [65 70 75]]
