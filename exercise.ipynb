# %%
import numpy as np

# %%
arr = np.array([1500,3000,5000])
lists = np.array([[10,15,8,12],[5,7,4,6],[2,3,2,4]])
print(arr.shape,arr.ndim)
print(lists.shape,lists.ndim)
# Out:
# (3,) 1
# (3, 4) 2

# %%
lists = lists+2
print(lists)
# Out:
# [[12 17 10 14]
#  [ 7  9  6  8]
#  [ 4  5  4  6]]

# %%
result = np.dot(arr,lists)
print(result)
print(np.sqrt(lists))
# Out:
# [59000 77500 53000 75000]
# [[3.46410162 4.12310563 3.16227766 3.74165739]
#  [2.64575131 3.         2.44948974 2.82842712]
#  [2.         2.23606798 2.         2.44948974]]

# %%
print(lists[1:2,:])
print(lists[:,:2])
# Out:
# [[7 9 6 8]]
# [[12 17]
#  [ 7  9]
#  [ 4  5]]

# %%
print(lists[2:,3:])
print(lists[:2,:2])
# Out:
# [[6]]
# [[12 17]
#  [ 7  9]]

# %%
print(lists.reshape(1,12))
# Out:
# [[12 17 10 14  7  9  6  8  4  5  4  6]]

# %%
print(lists.reshape(2,6))
# Out:
# [[12 17 10 14  7  9]
#  [ 6  8  4  5  4  6]]

# %%
print(np.linspace(0,100,10))
# Out:
# [  0.          11.11111111  22.22222222  33.33333333  44.44444444
#   55.55555556  66.66666667  77.77777778  88.88888889 100.        ]

# %%
print(np.random.randint(0,20,size=(3,4)))
# Out:
# [[17 14 11 13]
#  [11 18  2  7]
#  [ 1 19 19  0]]

# %%
np.random.rand(1,5)
# np.random.rand(3,4)
# Out:
# array([[0.2212531 , 0.70748766, 0.05861542, 0.39405831, 0.22073634]])

# %%
print(np.sum(lists))
# Out:
# 102

# %%
print(np.sum(lists,axis=1))
# Out:
# [53 30 19]
